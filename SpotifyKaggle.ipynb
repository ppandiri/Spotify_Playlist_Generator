# %%
import opendatasets as od
import pandas as pd
 
od.download(
    "https://www.kaggle.com/datasets/rodolfofigueroa/spotify-12m-songs/data")
# Out:
# Skipping, found downloaded files in "./spotify-12m-songs" (use force=True to force download)

# %%
file =('/Users/ppandiri/PycharmProjects/SpotifySongs/spotify-12m-songs/tracks_features.csv')
newData = pd.read_csv(file)
# Out:
#                         id                    name                      album  \
# 0   7lmeHLHBe4nmXzuXc0HDjk                 Testify  The Battle Of Los Angeles
# 1   1wsRitfRRtWyEapl0q22o8         Guerrilla Radio  The Battle Of Los Angeles
# 2   1hR0fIFK2qRG3f3RF70pb7        Calm Like a Bomb  The Battle Of Los Angeles
# 3   2lbASgTSoDO7MTuLAXlTW0               Mic Check  The Battle Of Los Angeles
# 4   1MQTmpYOZ6fcMQc56Hdo7T   Sleep Now In the Fire  The Battle Of Los Angeles
# 5   2LXPNLSMAauNJfnC58lSqY    Born of a Broken Man  The Battle Of Los Angeles
# 6   3moeHk8eIajvUEzVocXukf          Born As Ghosts  The Battle Of Los Angeles
# 7   4llunZfVXv3NvUzXVB3VVL                   Maria  The Battle Of Los Angeles
# 8   21Mq0NzFoVRvOmLTOnJjng  Voice of the Voiceless  The Battle Of Los Angeles
# 9   6s2FgJbnnMwFTpWJZzvb6z    New Millennium Homes  The Battle Of Los Angeles
# 10  7o2Razxnl33Jrgz4PpMYNa       Ashes In the Fall  The Battle Of Los Angeles
# ...

# %%
newData['artists'].head()
# Out:
# 0    ['Rage Against The Machine']
# 1    ['Rage Against The Machine']
# 2    ['Rage Against The Machine']
# 3    ['Rage Against The Machine']
# 4    ['Rage Against The Machine']
# Name: artists, dtype: object

# %%
data2 = newData[newData['artists'].apply(lambda x: 'A$AP Rocky' in x)]

# %%
data2.apply(lambda row: row.head(), axis=1)
# Out:
#                              id  \
# 435891   0fhoeNTlGRZgNlwfVLauFs
# 678287   35fIdI07pqeNT7hyCBh1bN
# 678289   3m4khUCvqSz5Rv2QS14rUh
# 754054   57q6BgYP4gN6hPQViCB3um
# 754055   3oHkMCVJyOcjg5FhfLc2Rq
# ...                         ...
# 1197473  57pOLYHz6mt5aMkOXa2Gis
# 1197474  0NFCFdJxEGCGO6EGkFCGgF
# 1197475  6PnmrzPJXoDBj5NKUCnC8e
# 1197476  5whbaLJtfCN3YNe9Rp5qj2
# 1203239  1ASG65sSdIL1z1NTPN4nhg
#
#                                                       name  \
# 435891                                       Too Many Gods
# 678287   Mattress REMIX (feat. A$AP Rocky, Playboi Cart...
# 678289   East Coast REMIX (feat. Busta Rhymes, A$AP Roc...
# 754054                                   Distorted Records
# 754055    A$AP Forever REMIX (feat. Moby, T.I. & Kid Cudi)
# ...                                                    ...
# 1197473        Ghetto Symphony (feat. Gunplay & A$AP Ferg)
# 1197474                                             Angels
# ...

# %%
print("hellojosh")
# Out:
# hellojosh

# %%
print("hellojosh")
# Out:
# hellojosh
