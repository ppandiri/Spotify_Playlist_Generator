# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %run SpotifyKaggle.ipynb


# Set up Spotipy client
client_credentials_manager = SpotifyClientCredentials(client_id='79c44db50adf46d895fb50cdccd7a563', client_secret='7bdf4da181894bf0a96d9b2ab79bffde')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Function to get features and popularity for a list of track ids
def get_track_features(ids):
    features = []
    for track_id in ids:
        track = sp.audio_features([track_id])[0]
        track2 = sp.track(track_id)
        features.append({
            'danceability': track['danceability'],
            'energy': track['energy'],
            'tempo': track['tempo'],
            'key': track['key'],
            'loudness': track['loudness'],
            'mode': track['mode'],
            'speechiness': track['speechiness'],
            'acousticness': track['acousticness'],
            'instrumentalness': track['instrumentalness'],
            'liveness': track['liveness'],
            'valence': track['valence'],
            'popularity': track2['popularity']
        })
    return features

# Example track IDs (replace with your own)
track_ids = newData.sample(n=1000)['id'].tolist()

# Get track features
track_features = get_track_features(track_ids)

# Create DataFrame from features
df = pd.DataFrame(track_features)

# Standardize feature columns
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[['danceability', 'energy', 'tempo', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence','popularity']])
# Compute correlation matrix
correlation_matrix = df.corr()

correlation_with_popularity = correlation_matrix['popularity'].abs().sort_values(ascending=False)

# Get the top three features
top_three_features = correlation_with_popularity.index[1:4]  # Exclude 'popularity' itself

print("Top three features:", top_three_features)

# %%
# Set up Spotipy client
client_credentials_manager = SpotifyClientCredentials(client_id='79c44db50adf46d895fb50cdccd7a563', client_secret='7bdf4da181894bf0a96d9b2ab79bffde')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Function to get features and popularity for a list of track ids
def get_track_features(ids):
    features = []
    for track_id in ids:
        track = sp.audio_features([track_id])[0]
        track2 = sp.track(track_id)
        features.append({
            'danceability': track['danceability'],
            'energy': track['energy'],
            'tempo': track['tempo'],
            'key': track['key'],
            'loudness': track['loudness'],
            'mode': track['mode'],
            'speechiness': track['speechiness'],
            'acousticness': track['acousticness'],
            'instrumentalness': track['instrumentalness'],
            'liveness': track['liveness'],
            'valence': track['valence'],
            'popularity': track2['popularity']
        })
    return features

# Example track IDs (replace with your own)
track_ids = newData.sample(n=10)['id'].tolist()

# Get track features
track_features = get_track_features(track_ids)

# Create DataFrame from features
df = pd.DataFrame(track_features)

# Standardize feature columns
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[['danceability', 'energy', 'tempo', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence','popularity']])

# Compute correlation matrix
correlation_matrix = df_scaled.corr()

# Get absolute correlation with the target variable 'popularity'
correlation_with_popularity = correlation_matrix['popularity'].abs().sort_values(ascending=False)

# Get the top three features
top_three_features = correlation_with_popularity.index[1:4]  # Exclude 'popularity' itself

print("Top three features:", top_three_features)
